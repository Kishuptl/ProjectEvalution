# %% [markdown]
# # Baseball Case Study

# %%
# import Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
bbds = pd.read_csv('baseball.csv')
bbds
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Converting csv dataset into dataframe

bbdf = pd.DataFrame(data=bbds)
bbdf
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Here the CSV dataset is converted into DataFrame.

# %% [markdown]
# # Performing EDA

# %%
bbdf.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset set contain 30 rows and 17 columns.

# %%
bbdf.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
bbdf.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# As per above this dataset 2 types (int & float).

# %%
bbdf.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# It shows the statistical information of numerical columns.

# %% [markdown]
# As per above data we can see there is no much difference between mean and median.

# %% [markdown]
# Here wecan also see that there is little difference between 75% and max value mean there might be some outlier present in the dataset.

# %% [markdown]
# We can also get Standard Deviation , minimum value and 25% from this method.

# %% [markdown]
# # Checking Null values

# %%
bbdf.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# checking null value using heatmap

sns.heatmap(bbdf.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above data and heatmap we can see that there is no null value present in dataset.

# %%
# checking values counts in each column for blank or white space

for i in bbdf.columns:
    print(bbdf[i].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [markdown]
# as per above we can see there is no blank space or white space in this dataset.

# %%
# checking number of unique values in each column.

bbdf.nunique().to_frame('No of unique values')
# Out:
#      No of unique values
# W                     24
# R                     28
# AB                    29
# H                     29
# 2B                    22
# 3B                    23
# HR                    27
# BB                    29
# SO                    29
# SB                    27
# RA                    30
# ER                    30
# ERA                   30
# CG                     9
# SHO                   12
# SV                    20
# E                     21

# %% [markdown]
# As per above we can see that there is unique value is present in each columns.

# %% [markdown]
# # Lets Check Correlation

# %%
bbdf_corr = bbdf.corr()
bbdf_corr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# heatmap for correlation 

sns.heatmap(bbdf_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# 1 . Univariate Analysis

# %%
print(bbdf['W'].value_counts())
sns.countplot(x=bbdf['W'] , palette='cool')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
# <AxesSubplot:xlabel='W', ylabel='count'>

# %% [markdown]
# in the above plot we can see that 'W' is very high at 1 points and high at 4 points.

# %%
print(bbdf['R'].value_counts())
sns.countplot(x=bbdf['R'] , palette='bright')
# Out:
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
# <AxesSubplot:xlabel='R', ylabel='count'>

# %% [markdown]
# In this plot we can see that 'R' is high at 2 points and equal at rest of all the points.

# %%
print(bbdf['AB'].value_counts())
sns.countplot(x=bbdf['AB'] , palette='icefire')
# Out:
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
# <AxesSubplot:xlabel='AB', ylabel='count'>

# %% [markdown]
# In the above plot 'AB' is high at 1 point and equal at rest of the points.

# %%
print(bbdf['H'].value_counts())
sns.countplot(x=bbdf['H'] , palette='cividis')
# Out:
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64
# <AxesSubplot:xlabel='H', ylabel='count'>

# %% [markdown]
# In the above plot we can see that 'H' is high at one point and equal at rest all the points.

# %%
print(bbdf['2B'].value_counts())
sns.countplot(x=bbdf['2B'] , palette='cool')
# Out:
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64
# <AxesSubplot:xlabel='2B', ylabel='count'>

# %% [markdown]
# In the above plot we can see that '2B' is high at 1 points

# %%
print(bbdf['3B'].value_counts())
sns.countplot(x=bbdf['3B'] , palette='bright')
# Out:
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64
# <AxesSubplot:xlabel='3B', ylabel='count'>

# %%
print(bbdf['HR'].value_counts())
sns.countplot(x=bbdf['HR'] , palette='icefire')
# Out:
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64
# <AxesSubplot:xlabel='HR', ylabel='count'>

# %% [markdown]
# in the above plot we can see that 'HR' is high at 3 points.

# %%
print(bbdf['BB'].value_counts())
sns.countplot(x=bbdf['BB'] , palette='cool')
# Out:
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: BB, dtype: int64
# <AxesSubplot:xlabel='BB', ylabel='count'>

# %% [markdown]
# In the above plot we can see that 'BB' is high t one points.

# %%
print(bbdf['SO'].value_counts())
sns.countplot(x=bbdf['SO'] , palette='bright')
# Out:
# 1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: SO, dtype: int64
# <AxesSubplot:xlabel='SO', ylabel='count'>

# %% [markdown]
# In the above plot we see that one point is high and rest all are equal.

# %%
print(bbdf['SB'].value_counts())
sns.countplot(x=bbdf['SB'] , palette='cividis')
# Out:
# 69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: SB, dtype: int64
# <AxesSubplot:xlabel='SB', ylabel='count'>

# %% [markdown]
# In the above plot 'SB' is very high at 1 point and high at 1 point.

# %%
print(bbdf['RA'].value_counts())
sns.countplot(x=bbdf['RA'] , palette='icefire')
# Out:
# 641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: RA, dtype: int64
# <AxesSubplot:xlabel='RA', ylabel='count'>

# %% [markdown]
# In this plot we see that all the values is equal for 'RA'.

# %%
print(bbdf['ER'].value_counts())
sns.countplot(x=bbdf['ER'] , palette='bright')
# Out:
# 601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: ER, dtype: int64
# <AxesSubplot:xlabel='ER', ylabel='count'>

# %% [markdown]
# 'ER' is also equal as per above plot.

# %%
print(bbdf['ERA'].value_counts())
sns.countplot(x=bbdf['ERA'] , palette='cividis')
# Out:
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64
# <AxesSubplot:xlabel='ERA', ylabel='count'>

# %% [markdown]
# ERA is also equal as per above plot.

# %%
print(bbdf['CG'].value_counts())
sns.countplot(x=bbdf['CG'] , palette='bright')
# Out:
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64
# <AxesSubplot:xlabel='CG', ylabel='count'>

# %% [markdown]
# As per above plot we can see that CG is highest at 1 and lowest at 11.

# %%
print(bbdf['SHO'].value_counts())
sns.countplot(x=bbdf['SHO'] , palette='deep')
# Out:
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64
# <AxesSubplot:xlabel='SHO', ylabel='count'>

# %% [markdown]
# As per above plot point 12 is highest .

# %%
print(bbdf['SV'].value_counts())
sns.countplot(x=bbdf['SV'] , palette='cool')
# Out:
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: SV, dtype: int64
# <AxesSubplot:xlabel='SV', ylabel='count'>

# %% [markdown]
# In the above plot 35 is highest .

# %%
print(bbdf['E'].value_counts())
sns.countplot(x=bbdf['E'] , palette='icefire')
# Out:
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64
# <AxesSubplot:xlabel='E', ylabel='count'>

# %% [markdown]
# As per above plot 86,88,90 is highest.

# %% [markdown]
# 2. Univariate Analysis

# %%
# comparing Win and Run

plt.figure(figsize=(10,4))
plt.title('Comparision between Win and Run')
sns.stripplot(x='W' , y='R' ,data=bbdf , palette='bright')
plt.show()

# %% [markdown]
# as per above plot Run and Win is equal.

# %%
# comparision between time at bat and base hit

plt.figure(figsize=(10,4))
plt.title('comparision between Time at Bat & Base Hit')
sns.scatterplot(x='AB' , y='H' , data=bbdf , palette='bright')
plt.show()

# %% [markdown]
# in this plot AB and H is scatter equally.

# %%
# comparision between 2B and 3B

plt.figure(figsize=(10,4))
plt.title('Comparision between 2B and 3B')
sns.stripplot(x='2B' , y='3B' , data=bbdf , palette='cool')
plt.show()

# %% [markdown]
# In this above plot 2B and 3B is correlated .

# %%
# comparision between HR and BB

plt.figure(figsize=(10,4))
plt.title('Comparision between Home runs and Base on ball')
sns.scatterplot(x='HR' , y='BB' , data=bbdf , palette='icefire')
plt.show()

# %% [markdown]
# In the above plot HR and BB as maximum run between 140 and 180.

# %%
# comparision between SO and SB

plt.figure(figsize=(10,4))
plt.title('Comparision between strikeout and Stolen base ')
sns.stripplot(x='SO' , y='SB' , data=bbdf , palette='bright')
plt.show()

# %%
# comparision between RA and ER

plt.figure(figsize=(10,4))
plt.title('Comparision between Average Run and Earned Run')
sns.stripplot(x='RA' , y='ER' , data=bbdf , palette='cool')
plt.show()

# %% [markdown]
# As per above we can see that RA increase with ER.

# %%
# comparision between ERA and CG

plt.figure(figsize=(10,4))
plt.title('comparision between Earned Run and Complete game.')
sns.scatterplot(x='ERA' , y='CG' ,data=bbdf , palette='cividis')
plt.show()

# %%
# comparision between SHO and SV

plt.figure(figsize=(10,4))
plt.title('Comparision between SHO and SV')
sns.scatterplot(x='SHO' , y='SV' , data=bbdf , palette='cool')
plt.show()

# %% [markdown]
# In the above plot we can SHO and SV has maximum value at point 10 and 12.5.

# %%
# comparision between E and AB

plt.figure(figsize=(10,4))
plt.title('comparision between E and AB')
sns.stripplot(x='E' , y='AB' , data=bbdf , palette='cool')
plt.show()

# %%
# Checking W  and ERA
sns.catplot(x='W' , y='ERA' , data=bbdf , palette='cividis' , kind='box')

# checking W and HR
sns.catplot(x='W' , y='HR' , data=bbdf , palette='spring_r' , kind='box')

# checking W and SHO
sns.catplot(x='W' , y='SHO' , data=bbdf , palette='spring_r' , kind='box')

# checking W and 3B
sns.catplot(x='W' , y='3B' , data=bbdf , palette='cividis' , kind='box')

# %% [markdown]
# In 1st plot Win rate and ERA is almost equal run.

# %% [markdown]
# In 2nd plot Win Rate less than Home Run .

# %% [markdown]
# In 3rd plot Win is high then SHO.

# %% [markdown]
# In 4th plot maximum of win is in between 20 to 35 of 3B.

# %%
# checking Win with SO
plt.figure(figsize=(10,6))
sns.catplot(x='SO' , col='W' ,data=bbdf , palette='cividis' ,kind='count')
plt.show()

# %% [markdown]
# In the above plot SO is maximum at W 68.

# %%
# checking W with ERA
plt.figure(figsize=(10,6))
sns.catplot(x='ERA' , col='W' , data=bbdf , palette='bright' , kind='count')
plt.show()

# %% [markdown]
# In the above plot maximum of ERA is at W 68.

# %%
# checking W with CG
sns.catplot(x='CG' ,hue='W' , data=bbdf ,palette='icefire' , kind='count')

# %% [markdown]
# as per above plot maximum CG is in between 0 to 1.

# %%
# comparision W with E 
sns.catplot(x='E' , hue='W' ,data=bbdf , palette='Set2_r' , kind='count')

# %% [markdown]
# In the above plot maximum of E is in between 88 to 90.

# %% [markdown]
# 3. Multivariate Analysis.

# %%
sns.pairplot(data=bbdf , hue='W' ,palette='bright')

# %% [markdown]
# The pairplot gives the pairwise relation between the feature on the basis of target 'W' and we can noticed the diagonal in the distribution plot.

# %%
bbdf.hist(bins=20, figsize=(10,10))
plt.show()

# %%
bbdf.plot(kind='kde' , subplots=True , figsize=(15,6))
# Out:
# array([<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#        <AxesSubplot:ylabel='Density'>], dtype=object)

# %% [markdown]
# # Checking Skewness

# %%
bbdf.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# as per above there is not much skewness present in the dataset.

# %% [markdown]
# # Checking for Outlier

# %%
plt.figure(figsize=(8,2))
bbdf.plot(kind='box' ,subplots=True  ,figsize=(10,10))
plt.show()

# %% [markdown]
# as per above we can see there is outlier present in some of the columns and we need to remove it.

# %% [markdown]
# # Removing outlier.

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(bbdf))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
bbdf_n = bbdf[(z<3).all(axis=1)]
bbdf_n
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
bbdf = bbdf_n

# %% [markdown]
# Now all the outlier is removed.

# %% [markdown]
# # Lets Check Correlation

# %%
bbdf.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.018360  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.433525  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.769159  0.490752  0.445604 -0.064653
# H   -0.018360  0.433525  0.769159  1.000000  0.528016  0.582024 -0.218711
# 2B   0.384886  0.469293  0.490752  0.528016  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.582024  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.218711 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.222271  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.371861 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.417877  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.244606 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280571 -0.224993  0.333731 -0.062094
# ...

# %%
# checking heatmap for correlation
plt.figure(figsize=(15,10))
sns.heatmap(bbdf.corr() , cmap='crest' , annot=True)
plt.show()

# %% [markdown]
# As per above heatmap we can see that there is multicollinearity is present in the dataset and we need to remove it.

# %%
# assigning x and y value 

x1 = bbdf.drop('W',axis=1)
y = bbdf['W']

# %%
x1.shape
# Out:
# (29, 16)

# %%
# for removing multicollinearity we need only columns from x , where rows=0 and columns=1

x1.shape[1]
# Out:
# 16

# %% [markdown]
# # Use of VIF for Multicollinearity

# %%
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_cal(x1):
    vif = pd.DataFrame()
    vif['Variables'] = x1.columns
    vif['VIF factor'] = [variance_inflation_factor(x1.values , i) for i in range(x1.shape[1])]
    return(vif)

vif_cal(x1)
# Out:
#    Variables    VIF factor
# 0          R   1684.071804
# 1         AB   4386.435411
# 2          H   4542.383497
# 3         2B    874.293076
# 4         3B     35.695117
# 5         HR    267.423009
# 6         BB    260.583556
# 7         SO    399.764153
# 8         SB     28.928494
# 9         RA  17975.314054
# 10        ER  50845.193939
# 11       ERA  23146.472801
# 12        CG      6.207366
# 13       SHO     30.820866
# 14        SV    117.346095
# 15         E     92.554014

# %%
# dropping column for removing multicollinearity

x1 = bbdf.drop(['RA','ER','ERA'],axis=1)

# %%
vif_cal(x1)
# Out:
#    Variables   VIF factor
# 0          W   564.982554
# 1          R  2734.436973
# 2         AB  3499.866321
# 3          H  4011.603213
# 4         2B   754.271452
# 5         3B    32.702070
# 6         HR   223.420387
# 7         BB   244.954001
# 8         SO   317.513717
# 9         SB    24.171288
# 10        CG     6.917502
# 11       SHO    25.997994
# 12        SV   214.733533
# 13         E    76.287063

# %% [markdown]
# now here we see that multicollinearity is removed.

# %%
x=x1

# %% [markdown]
# # Performing train_test_split method

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x ,y , test_size=.30 ,random_state=45)

# %%
x_train.shape
# Out:
# (20, 14)

# %%
x_test.shape
# Out:
# (9, 14)

# %%
y_train.shape
# Out:
# (20,)

# %%
y_test.shape
# Out:
# (9,)

# %% [markdown]
# # Applying Models

# %%
from sklearn.linear_model import LinearRegression ,Lasso ,Ridge , LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier , BaggingClassifier , AdaBoostClassifier
from sklearn.svm import SVC

# %%
from sklearn.metrics import r2_score, mean_squared_error , mean_absolute_error , accuracy_score
from sklearn.model_selection import cross_val_score

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train , y_train)
pred_dtc = dtc.predict(x_test)
print('Decision Tree Classifier')

print('r2 score:',r2_score(y_test,pred_dtc))
print('mean squared error:',mean_squared_error(y_test,pred_dtc))
print('mean absolute error:',mean_absolute_error(y_test,pred_dtc))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_dtc)))
print('Accuracy score:',accuracy_score(y_test,pred_dtc))
# Out:
# Decision Tree Classifier
# r2 score: -1.6863676863676864
# mean squared error: 223.33333333333334
# mean absolute error: 13.555555555555555
# squared root error: 14.944341180973263
# Accuracy score: 0.0

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
pred_lr = lr.predict(x_test)
print('Linear Regression')

print('r2 score:',r2_score(y_test,pred_lr))
print('mean squared error:',mean_squared_error(y_test,pred_lr))
print('mean absolute error:',mean_absolute_error(y_test,pred_lr))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# Linear Regression
# r2 score: 1.0
# mean squared error: 2.468258121224855e-28
# mean absolute error: 1.4210854715202004e-14
# squared root error: 1.5710691013525966e-14

# %%
ls = Lasso(alpha = 0.001)
ls.fit(x_train , y_train)
pred_ls = ls.predict(x_test)
print('Lasso Regression')

print('r2 score:',r2_score(y_test,pred_ls))
print('mean squared error:',mean_squared_error(y_test,pred_ls))
print('mean absolute error:',mean_absolute_error(y_test,pred_ls))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Lasso Regression
# r2 score: 0.9999999999188915
# mean squared error: 6.7430197765756604e-09
# mean absolute error: 6.379325422282515e-05
# squared root error: 8.211589235084558e-05

# %%
rd = Ridge(alpha=0.001)
rd.fit(x_train , y_train)
pred_rd = rd.predict(x_test)
print('Ridge Regression')

print('r2 score:',r2_score(y_test,pred_rd))
print('mean squared error:',mean_squared_error(y_test,pred_rd))
print('mean absolute error:',mean_absolute_error(y_test,pred_rd))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Ridge Regression
# r2 score: 0.9999999998328877
# mean squared error: 1.3893016136863934e-08
# mean absolute error: 9.337737759709499e-05
# squared root error: 0.00011786863932727794

# %%
lg = LogisticRegression()
lg.fit(x_train , y_train)
pred_lg = lg.predict(x_test)
print('Logistic Regression')

print('r2 score:',r2_score(y_test,pred_lg))
print('mean squared error:',mean_squared_error(y_test,pred_lg))
print('mean absolute error:',mean_absolute_error(y_test,pred_lg))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_lg)))
print('Accuracy score:',accuracy_score(y_test,pred_lg))
# Out:
# Logistic Regression
# r2 score: 0.14196614196614188
# mean squared error: 71.33333333333333
# mean absolute error: 7.555555555555555
# squared root error: 8.445906306213285
# Accuracy score: 0.0

# %%
knc = KNeighborsClassifier()
knc.fit(x_train , y_train)
pred_knc = knc.predict(x_test)
print('KNeighborsClassifier')

print('r2 score:',r2_score(y_test,pred_knc))
print('mean squared error:',mean_squared_error(y_test,pred_knc))
print('mean absolute error:',mean_absolute_error(y_test,pred_knc))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_knc)))
print('Accuracy score:',accuracy_score(y_test,pred_knc))
# Out:
# KNeighborsClassifier
# r2 score: -1.3468963468963469
# mean squared error: 195.11111111111111
# mean absolute error: 12.0
# squared root error: 13.968217893171309
# Accuracy score: 0.0

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train , y_train)
pred_rfc = rfc.predict(x_test)
print('Random Forest Classifier')

print('r2 score:',r2_score(y_test,pred_rfc))
print('mean squared error:',mean_squared_error(y_test,pred_rfc))
print('mean absolute error:',mean_absolute_error(y_test,pred_rfc))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_rfc)))
print('Accuracy score:',accuracy_score(y_test,pred_rfc))
# Out:
# Random Forest Classifier
# r2 score: 0.023017523017522912
# mean squared error: 81.22222222222223
# mean absolute error: 7.444444444444445
# squared root error: 9.01233722306385
# Accuracy score: 0.0

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train ,y_train)
pred_gbc = gbc.predict(x_test)
print('Gradient Boosting Classifier')

print('r2 score:',r2_score(y_test,pred_gbc))
print('mean squared error:',mean_squared_error(y_test,pred_gbc))
print('mean absolute error:',mean_absolute_error(y_test,pred_gbc))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_gbc)))
print('Accuracy score:',accuracy_score(y_test,pred_gbc))
# Out:
# Gradient Boosting Classifier
# r2 score: -1.7999702999703002
# mean squared error: 232.77777777777777
# mean absolute error: 13.0
# squared root error: 15.257056655127744
# Accuracy score: 0.0

# %%
bc = BaggingClassifier()
bc.fit(x_train , y_train)
pred_bc = bc.predict(x_test)
print('Bagging Classifier')

print('r2 score:',r2_score(y_test,pred_bc))
print('mean squared error:',mean_squared_error(y_test,pred_bc))
print('mean absolute error:',mean_absolute_error(y_test,pred_bc))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_bc)))
print('Accuracy score:',accuracy_score(y_test,pred_bc))
# Out:
# Bagging Classifier
# r2 score: -1.0114345114345116
# mean squared error: 167.22222222222223
# mean absolute error: 11.444444444444445
# squared root error: 12.931443160847216
# Accuracy score: 0.0

# %%
abc = AdaBoostClassifier()
abc.fit(x_train , y_train)
pred_abc = abc.predict(x_test)
print('AdaBoost Classifier')

print('r2 score:',r2_score(y_test,pred_abc))
print('mean squared error:',mean_squared_error(y_test,pred_abc))
print('mean absolute error:',mean_absolute_error(y_test,pred_abc))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_abc)))
print('Accuracy score:',accuracy_score(y_test,pred_abc))
# Out:
# AdaBoost Classifier
# r2 score: -1.288090288090288
# mean squared error: 190.22222222222223
# mean absolute error: 12.0
# squared root error: 13.792107243718133
# Accuracy score: 0.0

# %%
svc = SVC()
svc.fit(x_train , y_train)
pred_svc = svc.predict(x_test)
print('Support Vector Classifier')

print('r2 score:',r2_score(y_test,pred_svc))
print('mean squared error:',mean_squared_error(y_test,pred_svc))
print('mean absolute error:',mean_absolute_error(y_test,pred_svc))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_svc)))
print('Accuracy score:',accuracy_score(y_test,pred_svc))
# Out:
# Support Vector Classifier
# r2 score: 0.3157113157113156
# mean squared error: 56.888888888888886
# mean absolute error: 6.888888888888889
# squared root error: 7.542472332656507
# Accuracy score: 0.0

# %%
from sklearn.linear_model import LinearRegression ,Lasso ,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor , GradientBoostingRegressor , BaggingRegressor

# %%
models =[LinearRegression(),Lasso(alpha=0.01),Ridge(alpha=0.01),DecisionTreeRegressor(),KNeighborsRegressor(),RandomForestRegressor(),GradientBoostingRegressor(),BaggingRegressor()]

for m in models:
    m.fit(x_train , y_train)
    pred_m = m.predict(x_test)
    print(m)
    print('r2 score:',r2_score(y_test,pred_m))
    print('mean squared error:',mean_squared_error(y_test,pred_m))
    print('mean absolute error:',mean_absolute_error(y_test,pred_m))
    print('squared root error:',np.sqrt(mean_squared_error(y_test,pred_m)))
    print('\n')
# Out:
# LinearRegression()
# r2 score: 1.0
# mean squared error: 2.468258121224855e-28
# mean absolute error: 1.4210854715202004e-14
# squared root error: 1.5710691013525966e-14
#
#
# Lasso(alpha=0.01)
# r2 score: 0.9999999918891506
# mean squared error: 6.743019776518608e-07
# mean absolute error: 0.0006379325422440414
# squared root error: 0.0008211589235049819
#
#
# Ridge(alpha=0.01)
# r2 score: 0.9999999833043731
# mean squared error: 1.388004337434945e-06
# mean absolute error: 0.0009333374158997129
# squared root error: 0.0011781359588073632
#
#
# DecisionTreeRegressor()
# r2 score: 0.12459162459162454
# mean squared error: 72.77777777777777
# mean absolute error: 6.333333333333333
# squared root error: 8.530989261379817
#
#
# KNeighborsRegressor()
# r2 score: 0.36414612414612413
# mean squared error: 52.86222222222222
# mean absolute error: 5.777777777777778
# squared root error: 7.270641114937679
#
#
# RandomForestRegressor()
# r2 score: 0.9078501039501039
# ...

# %% [markdown]
# # Cross Validation Score

# %%
score1 = cross_val_score(dtc,x,y,cv=2)
print('score1:',score1)
print('score1 mean:',score1.mean())
print('score1 std:',score1.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_dtc)-score1.mean())*100)
# Out:
# score1: [0.13333333 0.        ]
# score1 mean: 0.06666666666666667
# score1 std: 0.06666666666666667
# Difference between r2 score and mean: -175.3034353034353

# %%
score2 = cross_val_score(lr,x,y,cv=2)
print('score2:',score2)
print('score2 mean:',score2.mean())
print('score2 std:',score2.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_lr)-score2.mean())*100)
# Out:
# score2: [0.84569844 1.        ]
# score2 mean: 0.9228492198098792
# score2 std: 0.07715078019012073
# Difference between r2 score and mean: 7.715078019012078

# %%
score3 = cross_val_score(ls,x,y,cv=2)
print('score3:',score3)
print('score3 mean:',score3.mean())
print('score3 std:',score3.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_ls)-score3.mean())*100)
# Out:
# score3: [1. 1.]
# score3 mean: 0.9999999997370759
# score3 std: 1.1557260704010641e-10
# Difference between r2 score and mean: 1.8181567362773876e-08

# %%
score4 = cross_val_score(rd,x,y,cv=2)
print('score4:',score4)
print('score4 mean:',score4.mean())
print('score4 std:',score4.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_rd)-score4.mean())*100)
# Out:
# score4: [0.84572067 1.        ]
# score4 mean: 0.922860335947451
# score4 std: 0.07713966164629732
# Difference between r2 score and mean: 7.713966388543669

# %%
score5 = cross_val_score(lg,x,y,cv=2)
print('score5:',score5)
print('score5 mean:',score5.mean())
print('score5 std:',score5.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_lg)-score5.mean())*100)
# Out:
# score5: [0. 0.]
# score5 mean: 0.0
# score5 std: 0.0
# Difference between r2 score and mean: 14.196614196614188

# %%
score6 = cross_val_score(knc,x,y,cv=2)
print('score6:',score3)
print('score6 mean:',score6.mean())
print('score6 std:',score6.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_knc)-score6.mean())*100)
# Out:
# score6: [1. 1.]
# score6 mean: 0.03571428571428571
# score6 std: 0.03571428571428571
# Difference between r2 score and mean: -138.26106326106327

# %%
score7 = cross_val_score(rfc,x,y,cv=2)
print('score7:',score7)
print('score7 mean:',score7.mean())
print('score7 std:',score7.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_rfc)-score7.mean())*100)
# Out:
# score7: [0.06666667 0.        ]
# score7 mean: 0.03333333333333333
# score7 std: 0.03333333333333333
# Difference between r2 score and mean: -1.031581031581042

# %%
score8 = cross_val_score(gbc,x,y,cv=2)
print('score8:',score8)
print('score8 mean:',score8.mean())
print('score8 std:',score8.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_gbc)-score8.mean())*100)
# Out:
# score8: [0.13333333 0.        ]
# score8 mean: 0.06666666666666667
# score8 std: 0.06666666666666667
# Difference between r2 score and mean: -186.6636966636967

# %%
score9 = cross_val_score(bc,x,y,cv=2)
print('score9:',score9)
print('score9 mean:',score9.mean())
print('score9 std:',score9.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_bc)-score9.mean())*100)
# Out:
# score9: [0.06666667 0.        ]
# score9 mean: 0.03333333333333333
# score9 std: 0.03333333333333333
# Difference between r2 score and mean: -104.4767844767845

# %%
score10 = cross_val_score(abc,x,y,cv=2)
print('score10:',score10)
print('score10 mean:',score10.mean())
print('score10 std:',score10.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_abc)-score10.mean())*100)
# Out:
# score10: [0.06666667 0.        ]
# score10 mean: 0.03333333333333333
# score10 std: 0.03333333333333333
# Difference between r2 score and mean: -132.14236214236215

# %%
score11 = cross_val_score(svc,x,y,cv=2)
print('score11:',score11)
print('score11 mean:',score11.mean())
print('score11 std:',score11.std())
print('Difference between r2 score and mean:',(r2_score(y_test,pred_svc)-score11.mean())*100)
# Out:
# score11: [0.06666667 0.        ]
# score11 mean: 0.03333333333333333
# score11 std: 0.03333333333333333
# Difference between r2 score and mean: 28.237798237798227

# %%
models =[LinearRegression(),Lasso(alpha=0.01),Ridge(alpha=0.01),DecisionTreeRegressor(),KNeighborsRegressor(),RandomForestRegressor(),GradientBoostingRegressor(),BaggingRegressor()]

for i in models:
    score = cross_val_score(i,x,y,cv=2)
    print(i)
    print('score:',score)
    print('score mean:',score.mean())
    print('score std:',score.std())
    print('Differnce between r2 score and mean:',(r2_score(y_test,pred_m)-score.mean())*100)
    print('\n')
# Out:
# LinearRegression()
# score: [0.84569844 1.        ]
# score mean: 0.9228492198098792
# score std: 0.07715078019012073
# Differnce between r2 score and mean: -10.763389459455396
#
#
# Lasso(alpha=0.01)
# score: [0.99999999 0.99999996]
# score mean: 0.9999999737075804
# score std: 1.1557260981565065e-08
# Differnce between r2 score and mean: -18.478464849225517
#
#
# Ridge(alpha=0.01)
# score: [0.84592052 0.99999976]
# score mean: 0.9229601421336733
# score std: 0.07703961806509857
# Differnce between r2 score and mean: -10.774481691834803
#
#
# DecisionTreeRegressor()
# score: [0.53965295 0.67317746]
# score mean: 0.60641520429886
# score std: 0.0667622572172597
# Differnce between r2 score and mean: 20.880012091646527
#
#
# KNeighborsRegressor()
# score: [-0.87550552 -0.1915655 ]
# score mean: -0.5335355082520488
# score std: 0.341970013044381
# Differnce between r2 score and mean: 134.87508334673743
#
#
# RandomForestRegressor()
# score: [0.47132368 0.67758143]
# ...

# %% [markdown]
# As per above we can see the Lasso has the lowest value in difference between r2 score and mean . Hence it will be used for prediction.

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'alpha':[1.0,0.5,.4,2],'fit_intercept':[True,False],
             'positive':[False,True]
             }

# %%
grid = GridSearchCV(Lasso(),parameters,cv=2)
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=2, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 0.5, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True]})

# %%
 grid.best_params_
# Out:
# {'alpha': 0.4, 'fit_intercept': False, 'positive': False}

# %%
model = Lasso(alpha= 0.4,)
model.fit(x_train,y_train)
pred = model.predict(x_test)
print('r2 score:',r2_score(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('mean squared error:',mean_squared_error(y_test,pred))
print('squared root error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score: 0.9999863014534665
# mean absolute error: 0.026256358460772036
# mean squared error: 0.0011388396587262766
# squared root error: 0.03374669848631532

# %%
import pickle
filename = 'baseball.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model = pickle.load(open('baseball.pkl','rb'))
result =loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.99863014534665

# %%
conclusion = pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                    0          1          2          3          4          5  \
# Predicted  79.023038  79.995055  91.968496  68.057486  87.008356  87.994057
# Original   79.000000  80.000000  92.000000  68.000000  87.000000  88.000000
#
#                    6          7          8
# Predicted  67.039218  85.995269  68.061087
# Original   67.000000  86.000000  68.000000

# %% [markdown]
# # Finalizing Model

# %%
final_ls= Lasso(alpha=0.01)

# %%
final_ls.fit(x_train , y_train)
pred = final_ls.predict(x_test)
print(pred)
# Out:
# [79.00056003 79.9998791  91.99922141 68.00141076 87.00020119 87.99985951
#  67.00093646 85.99988837 68.00148134]

# %% [markdown]
# # Saving Best Model

# %%
import joblib

# %%
joblib.dump(final_ls,'base_ball.pkl')
# Out:
# ['base_ball.pkl']

# %%
# predicting saved model

model = joblib.load('base_ball.pkl')

# prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([79.00056003, 79.9998791 , 91.99922141, 68.00141076, 87.00020119,
#        87.99985951, 67.00093646, 85.99988837, 68.00148134])

# %% [markdown]
# # Checking predicted model is correct result

# %%
a = np.array(y_test)
bbdf = pd.DataFrame()
bbdf['predicted'] = prediction
bbdf['original'] = a
bbdf
# Out:
#    predicted  original
# 0  79.000560        79
# 1  79.999879        80
# 2  91.999221        92
# 3  68.001411        68
# 4  87.000201        87
# 5  87.999860        88
# 6  67.000936        67
# 7  85.999888        86
# 8  68.001481        68
